# %% [markdown]
# # Data Dive 2: World Happiness

# %% [markdown]
# # Nottely's Code

# %%
import numpy as np
import pandas as pd
#used to store and echange complex data: allows  you to save python objects and then later load them back into memory
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#%matplotlib inline

# %%
#checking working directory
# %pwd
# %cd C:/Users/14048/OneDrive - Middle Tennessee State University/Documents/School/DATA3500/Datadives/Dive2/dive2data
# Out:
# C:\Users\14048\OneDrive - Middle Tennessee State University\Documents\School\DATA3500\Datadives\Dive2\dive2data

# %%
data = pd.read_csv("2019.csv", index_col=0)

# %%
data.head()
# Out:
#              Country or region  Score  GDP per capita  Social support  \
# Overall rank
# 1                      Finland  7.769           1.340           1.587
# 2                      Denmark  7.600           1.383           1.573
# 3                       Norway  7.554           1.488           1.582
# 4                      Iceland  7.494           1.380           1.624
# 5                  Netherlands  7.488           1.396           1.522
#
#               Healthy life expectancy  Freedom to make life choices  \
# Overall rank
# 1                               0.986                         0.596
# 2                               0.996                         0.592
# 3                               1.028                         0.603
# 4                               1.026                         0.591
# 5                               0.999                         0.557
#
#               Generosity  Perceptions of corruption
# Overall rank
# ...

# %%
#making all variable names lower case for convience
data.columns = data.columns.str.lower()
data.head()
# Out:
#              country or region  score  gdp per capita  social support  \
# Overall rank
# 1                      Finland  7.769           1.340           1.587
# 2                      Denmark  7.600           1.383           1.573
# 3                       Norway  7.554           1.488           1.582
# 4                      Iceland  7.494           1.380           1.624
# 5                  Netherlands  7.488           1.396           1.522
#
#               healthy life expectancy  freedom to make life choices  \
# Overall rank
# 1                               0.986                         0.596
# 2                               0.996                         0.592
# 3                               1.028                         0.603
# 4                               1.026                         0.591
# 5                               0.999                         0.557
#
#               generosity  perceptions of corruption
# Overall rank
# ...

# %%
data.isnull().sum()
# Out:
# country or region               0
# score                           0
# gdp per capita                  0
# social support                  0
# healthy life expectancy         0
# freedom to make life choices    0
# generosity                      0
# perceptions of corruption       0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
import statsmodels.api as sm



# Define the independent variables
independent_vars = [
    "gdp per capita",
    "social support",
    "healthy life expectancy",
    "freedom to make life choices",
    "generosity",
    "perceptions of corruption"
]

# Add a constant term (intercept) to the independent variables
X = sm.add_constant(data[independent_vars])

# Define the dependent variable
y = data["score"]

# Fit the multiple linear regression model
model = sm.OLS(y, X).fit()

# Get the regression summary
summary = model.summary()

print(summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  score   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     87.62
# Date:                Sun, 29 Oct 2023   Prob (F-statistic):           2.40e-46
# Time:                        14:10:15   Log-Likelihood:                -119.76
# No. Observations:                 156   AIC:                             253.5
# Df Residuals:                     149   BIC:                             274.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            1.7952      0.211      8.505      0.000       1.378       2.212
# ...

# %%
# Correlation Matrix

#makes data frame with only varibles with numberic values
numeric_features = data.select_dtypes(include=[np.number])

#correlation based on the numberic features
correlation = numeric_features.corr()


import seaborn as sns

f, ax = plt.subplots(figsize=(14, 12))
sns.heatmap(correlation, annot=True, fmt=".2f", cmap='coolwarm', ax=ax)
plt.title('Correlation of Numeric Features', y=1, size=16)
plt.show()
